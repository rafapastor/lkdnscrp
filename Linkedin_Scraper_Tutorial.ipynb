# %%
#Import dependencies
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# %%
title = "developer"  # Job title
location = "Spain"  # Job location
start = 0  # Starting point for pagination

# %%
# Construct the URL for LinkedIn job search
list_url = f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords={title}&location={location}&start={start}&f_TPR=r86400&f_WT=2"

# Send a GET request to the URL and store the response
response = requests.get(list_url)

#Get the HTML, parse the response and find all list items(jobs postings)
list_data = response.text
list_soup = BeautifulSoup(list_data, "html.parser")
page_jobs = list_soup.find_all("li")
# Out:
# [<li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3955976154" data-impression-id="jobs-search-result-0" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="1" data-tracking-id="nhW7d5u9nrvjV2Ptp6+Nzg==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/front-end-developer-react-at-idealista-3955976154?position=1&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=nhW7d5u9nrvjV2Ptp6%2BNzg%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Front-End Developer (React)
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/D4D0BAQELbw0jk9sX5A/company-logo_100_100/0/1720424487902/idealista_com_logo?e=2147483647&amp;v=beta&amp;t=3oUTdnd3zrJ40P0WUCDrlUeHyvq-vgAW7oDOOYSRBMc" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Front-End Developer (React)
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://es.linkedin.com/company/idealista-com?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             idealista
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Madrid, Community of Madrid, Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       6 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3981216443" data-impression-id="jobs-search-result-1" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="2" data-tracking-id="Pfc+9LJYRHVnAHKzd5tECw==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/desarrollador-a-react-100%25-remoto-at-knowmad-mood-3981216443?position=2&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=Pfc%2B9LJYRHVnAHKzd5tECw%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Desarrollador/a React (100% REMOTO)
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/D4D0BAQG_TIqvuI7kCA/company-logo_100_100/0/1720435347792/knowmad_mood_logo?e=2147483647&amp;v=beta&amp;t=yW2UgU_OZ65nDTPVwtAb4ilV-NHYD50tTei1K4TbikM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Desarrollador/a React (100% REMOTO)
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://es.linkedin.com/company/knowmad-mood?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             knowmad mood
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       3 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3805703163" data-impression-id="jobs-search-result-2" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="3" data-tracking-id="v/PgawKfXG3rtjAepdwbeg==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/desarrollador-a-fullstack-at-inetum-3805703163?position=3&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=v%2FPgawKfXG3rtjAepdwbeg%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Desarrollador/a FullStack
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/C4D0BAQFo_2-ZPy_psw/company-logo_100_100/0/1630558676103/inetum_logo?e=2147483647&amp;v=beta&amp;t=E6R9wkMOHbWK0v6pnEDjvWeOGmiXX_d4Zei2FzqF3Ew" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Desarrollador/a FullStack
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://fr.linkedin.com/company/inetum?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Inetum
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Greater Madrid Metropolitan Area
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       6 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3990699049" data-impression-id="jobs-search-result-3" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="4" data-tracking-id="jHBYiD8uBjCvrHJ9Z9Evyg==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/%F0%9F%8F%A0-python-developer-java-r%F0%9F%8F%A0-100%25-teletrabajo-at-knowmad-mood-3990699049?position=4&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=jHBYiD8uBjCvrHJ9Z9Evyg%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         🏠 Python Developer  / Java / R🏠 (100% teletrabajo)
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/D4D0BAQG_TIqvuI7kCA/company-logo_100_100/0/1720435347792/knowmad_mood_logo?e=2147483647&amp;v=beta&amp;t=yW2UgU_OZ65nDTPVwtAb4ilV-NHYD50tTei1K4TbikM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         🏠 Python Developer  / Java / R🏠 (100% teletrabajo)
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://es.linkedin.com/company/knowmad-mood?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             knowmad mood
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       6 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3982429401" data-impression-id="jobs-search-result-4" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="5" data-tracking-id="EUSdyqPGLNXVMM86uI/nNA==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/java-developer-100%25-remoto-at-primeit-espa%C3%B1a-3982429401?position=5&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=EUSdyqPGLNXVMM86uI%2FnNA%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         JAVA DEVELOPER | 100% REMOTO
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/D4D0BAQF_spDjkCxl5Q/company-logo_100_100/0/1720429067404?e=2147483647&amp;v=beta&amp;t=82tKthz6ePZUGfjwHUkDIiKXpdvyy8MlYMtz137918E" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         JAVA DEVELOPER | 100% REMOTO
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://es.linkedin.com/company/primeit-espa%C3%B1a?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             PrimeIT España
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       6 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3995900853" data-impression-id="jobs-search-result-5" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="6" data-tracking-id="vxyaN+xdHy3pNhmLMwNx4Q==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/desarrollador-de-front-end-at-mpforall-business-and-collaboration-sl-3995900853?position=6&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=vxyaN%2BxdHy3pNhmLMwNx4Q%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Desarrollador de front-end
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4 artdeco-entity-image--ghost" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Desarrollador de front-end
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/mpforall-business-and-collaboration-sl?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             MPFORALL BUSINESS AND COLLABORATION SL
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       18 minutes ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3996220742" data-impression-id="jobs-search-result-6" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="7" data-tracking-id="mYKeStpQrkff5CSzTwORfA==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/fullstack-developer-php-symfony-react-at-algoteque-innovation-hub-3996220742?position=7&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=mYKeStpQrkff5CSzTwORfA%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         FullStack Developer (PHP, Symfony, React)
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/D4D0BAQGoJu2b13uCag/company-logo_100_100/0/1683796331366/algoteque_logo?e=2147483647&amp;v=beta&amp;t=orKzZDmpuH4gy0EB2ClTlg7jnVXfYhlroIZSSWvYtlU" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         FullStack Developer (PHP, Symfony, React)
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://pl.linkedin.com/company/algoteque?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             ALGOTEQUE Innovation Hub
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Barcelona, Catalonia, Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/8zmuwb93gzlb935fk4ao4z779" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Be an early applicant
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       6 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3965558951" data-impression-id="jobs-search-result-7" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="8" data-tracking-id="cbDvvkgId6XvI/kk1fo+lA==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/java-software-developer-100%25-remoto-at-knowmad-mood-3965558951?position=8&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=cbDvvkgId6XvI%2Fkk1fo%2BlA%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Java Software Developer - 100% remoto
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/D4D0BAQG_TIqvuI7kCA/company-logo_100_100/0/1720435347792/knowmad_mood_logo?e=2147483647&amp;v=beta&amp;t=yW2UgU_OZ65nDTPVwtAb4ilV-NHYD50tTei1K4TbikM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Java Software Developer - 100% remoto
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://es.linkedin.com/company/knowmad-mood?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             knowmad mood
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       4 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3994686184" data-impression-id="jobs-search-result-8" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="9" data-tracking-id="RkMf+QYaOCJX+TlLseVrcg==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/frontend-developer-at-remote-and-talent-3994686184?position=9&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=RkMf%2BQYaOCJX%2BTlLseVrcg%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Frontend Developer
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/C4D0BAQGuiVz9vNH6gA/company-logo_100_100/0/1677498833119/remote_and_talent_logo?e=2147483647&amp;v=beta&amp;t=gBzyGoGUoVTGbaN4H9eVV4HtNMEb4grQJxJkXP3Cqa0" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Frontend Developer
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://es.linkedin.com/company/remote-and-talent?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Remote and Talent
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate" datetime="2024-08-07">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       1 day ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>, <li>
# <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3971137829" data-impression-id="jobs-search-result-9" data-reference-id="lF5XpnN/L6f7s77lHX1GVw==" data-row="10" data-tracking-id="kgsibFmSeA+0iB11u8XbWQ==">
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/full-stack-developer-php-at-idealista-3971137829?position=10&amp;pageNum=0&amp;refId=lF5XpnN%2FL6f7s77lHX1GVw%3D%3D&amp;trackingId=kgsibFmSeA%2B0iB11u8XbWQ%3D%3D&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Full Stack Developer PHP
#
#
#           </span>
# </a>
# <div class="search-entity-media">
# <img alt="" class="artdeco-entity-image artdeco-entity-image--square-4" data-delayed-url="https://media.licdn.com/dms/image/D4D0BAQELbw0jk9sX5A/company-logo_100_100/0/1720424487902/idealista_com_logo?e=2147483647&amp;v=beta&amp;t=3oUTdnd3zrJ40P0WUCDrlUeHyvq-vgAW7oDOOYSRBMc" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/6puxblwmhnodu6fjircz4dn4h"/>
# </div>
# <div class="base-search-card__info">
# <h3 class="base-search-card__title">
#
#         Full Stack Developer PHP
#
#           </h3>
# <h4 class="base-search-card__subtitle">
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://es.linkedin.com/company/idealista-com?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             idealista
#           </a>
# </h4>
# <!-- -->
# <div class="base-search-card__metadata">
# <span class="job-search-card__location">
#             Spain
#           </span>
# <div class="job-posting-benefits text-sm">
# <icon class="job-posting-benefits__icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/3p1v0uhy7uq0cm5zdvzp4eo18" data-svg-class-name="job-posting-benefits__icon-svg"></icon>
# <span class="job-posting-benefits__text">
#           Actively Hiring
# <!-- --> </span>
# </div>
# <time class="job-search-card__listdate--new" datetime="2024-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       6 hours ago
#
#           </time>
# <!-- -->
# </div>
# </div>
# <!-- -->
# </div>
# </li>]

# %%
#Create an empty list to store the job postings
id_list = []

# %%
#Itetrate through job postings to find job ids
for job in page_jobs:
    base_card_div = job.find("div", {"class": "base-card"})
    job_id = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id)
    id_list.append(job_id)
# Out:
# 3955976154
# 3981216443
# 3805703163
# 3990699049
# 3982429401
# 3995900853
# 3996220742
# 3965558951
# 3994686184
# 3971137829

# %%
# Initialize an empty list to store job information
job_list = []

# Loop through the list of job IDs and get each URL
for job_id in id_list:
    # Construct the URL for each job using the job ID
    print(job_id)
    job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
    
    # Send a GET request to the job URL and parse the reponse
    job_response = requests.get(job_url)
    print(job_response.status_code)
    job_soup = BeautifulSoup(job_response.text, "html.parser")
    
     # Create a dictionary to store job details
    job_post = {}
    
    # Try to extract and store the job title
    try:
        job_post["job_title"] = job_soup.find("h2", {"class":"top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post["job_title"] = None
        
    # Try to extract and store the company name
    try:
        job_post["company_name"] = job_soup.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except:
        job_post["company_name"] = None
        
    # Try to extract and store the time posted
    try:
        job_post["time_posted"] = job_soup.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post["time_posted"] = None
        
    # Try to extract and store the number of applicants
    try:
        job_post["num_applicants"] = job_soup.find("span", {"class": "num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet"}).text.strip()
    except:
        job_post["num_applicants"] = None
    
        
    # Append the job details to the job_list
    job_list.append(job_post)
# Out:
# 3955976154
# 429
# 3981216443
# 429
# 3805703163
# 200
# 3990699049
# 429
# 3982429401
# 429
# 3995900853
# 429
# 3996220742
# 429
# 3965558951
# 200
# 3994686184
# 200
# 3971137829
# 429

# %%
#Check if the list contains all the desired data
job_list
# Out:
# [{'job_title': None,
#   'company_name': None,
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': None,
#   'company_name': None,
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': 'Desarrollador/a FullStack',
#   'company_name': 'Inetum',
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': None,
#   'company_name': None,
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': None,
#   'company_name': None,
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': None,
#   'company_name': None,
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': None,
#   'company_name': None,
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': 'Java Software Developer - 100% remoto',
#   'company_name': 'knowmad mood',
#   'time_posted': None,
#   'num_applicants': None},
#  {'job_title': 'Frontend Developer',
#   'company_name': 'Remote and Talent',
#   'time_posted': '1 day ago',
#   'num_applicants': '146 applicants'},
#  {'job_title': None,
#   'company_name': None,
#   'time_posted': None,
#   'num_applicants': None}]

# %%
# Create a pandas DataFrame using the list of job dictionaries 'job_list'
jobs_df = pd.DataFrame(job_list)
jobs_df
# Out:
#                                job_title       company_name time_posted  \
# 0                                   None               None        None
# 1                                   None               None        None
# 2              Desarrollador/a FullStack             Inetum        None
# 3                                   None               None        None
# 4                                   None               None        None
# 5                                   None               None        None
# 6                                   None               None        None
# 7  Java Software Developer - 100% remoto       knowmad mood        None
# 8                     Frontend Developer  Remote and Talent   1 day ago
# 9                                   None               None        None
#
#    num_applicants
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8  146 applicants
# 9            None

# %%
#Save data to CSV file
jobs_df.to_csv('jobs.csv', index = False)
